# %% [markdown]
# <a href="https://colab.research.google.com/github/thanish-A/Python-programming-/blob/main/Python_programming_day_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x = int(input("Enter x: "))
y = int(input("Enter y: "))

if x > 0 and y > 0:
    print("1st Quadrant")
elif x < 0 and y > 0:
    print("2nd Quadrant")
elif x < 0 and y < 0:
    print("3rd Quadrant")
elif x > 0 and y < 0:
    print("4th Quadrant")
else:
    print("On Axis / Origin")
# Out:
# Enter x: 3
# Enter y: 5
# 1st Quadrant

# %%
year = int(input("Enter year: "))
month = int(input("Enter month: "))

if month < 1 or month > 12:
    print("Invalid Month")
else:
    if month in [1,3,5,7,8,10,12]:
        print("31 days")
    elif month in [4,6,9,11]:
        print("30 days")
    else:
        if year % 400 == 0 or (year % 4 == 0 and year % 100 != 0):
            print("29 days")
        else:
            print("28 days")

# %%
marks = int(input("Enter marks: "))

if marks >= 80:
    print("Grade A")
elif marks >= 60:
    print("Grade B")
elif marks >= 40:
    print("Grade C")
else:
    print("Fail")

# %%
units = int(input("Enter units: "))
bill = 0

if units <= 100:
    bill = 0
elif units <= 300:
    bill = (units - 100) * 5
else:
    bill = (200 * 5) + ((units - 300) * 10)

if units > 500:
    bill = bill + bill * 0.10

print("Bill =", bill)

# %%
a = int(input("Enter side1: "))
b = int(input("Enter side2: "))
c = int(input("Enter side3: "))

if a+b > c and a+c > b and b+c > a:
    print("Valid Triangle")
else:
    print("Invalid Triangle")

# %%
num = int(input("Enter number: "))
product = 1

while num > 0:
    digit = num % 10
    product *= digit
    num = num // 10

print("Product =", product)

# %%
num = int(input("Enter number: "))
sum_factors = 0

for i in range(1, num + 1):
    if num % i == 0:
        sum_factors += i

print("Sum =", sum_factors)

# %%
num = int(input("Enter decimal number: "))
binary = ""

while num > 0:
    binary = str(num % 2) + binary
    num = num // 2

print("Binary =", binary)

# %%
num = int(input("Enter number: "))
largest = 0

while num > 0:
    digit = num % 10
    if digit > largest:
        largest = digit
    num = num // 10

print("Largest digit =", largest)

# %%
n = int(input("Enter N: "))

for num in range(2, n + 1):
    prime = True

    for i in range(2, num):
        if num % i == 0:
            prime = False
            break

    if prime:
        print(num, end=" ")
